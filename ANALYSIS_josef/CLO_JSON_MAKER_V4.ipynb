# %% [markdown]
# # CLO DUAL JSON MAKER COVER ARC DATA
# Centerpoint 기준으로 arrangement point하지 않고
#
# 각 패널의 Mean Point를 기준으로 arrangement point 생성
#
# ++ 추가적으로 ARC 2 Bezier data에 대해서도 다룰 수 있게 됨.ㅋ.ㅋ

# %%
import os, sys
sys.path.append(os.path.dirname(os.getcwd()))
from glob import glob
import math
from pprint import pprint
import torch

import pygarment as pyg
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import time

from tqdm import tqdm
import json
import random

import trimesh
from ANALYSIS.analysis_utils import (
    plot_panel_info,
    visualize_meshes_plotly,
    v_id_map
)
# Out:
# None

# %%
# #TODO: 걍 한방 삼계탕 급.
# import math
# import numpy as np
# import matplotlib.pyplot as plt

# def single_arc_to_cubic_bezier(start_x, start_y, end_x, end_y, r,
#                                rotation_angle,
#                                large_arc_flag,
#                                sweep_flag):
#     """
#     하나의 Arc (SVG 파라미터) -> 하나의 Cubic Bezier (컨트롤포인트 2개) 근사.
#     회전각 rotation_angle=0 으로 가정합니다.
    
#     반환값: (P0, P1, P2, P3),  # Cubic Bezier 4개 점
#            (cx, cy),          # 계산된 호의 중심
#            (theta_start, theta_end, delta_theta) # 각도 정보
#     """
#     # 1) 시작점과 끝점
#     dx = end_x - start_x
#     dy = end_y - start_y
#     d = math.hypot(dx, dy)
#     if sweep_flag == True:
#         sweep_flag = False
#     else:
#         sweep_flag = True
#     # 만약 두 점 사이 거리가 2r보다 크면, 실제로는 호를 만들기 어려워서
#     # SVG 사양에서는 반지름을 늘려 강제 조정하지만, 여기서는 간단히 처리
#     if d > 2*r:
#         r = d/2

#     mid_x = (start_x + end_x)/2.0
#     mid_y = (start_y + end_y)/2.0

#     # 2) 중심 (cx, cy) 계산 (endpoint-to-center)
#     # chord midpoint -> center distance
#     h = math.sqrt(abs(r**2 - (d/2.0)**2))
#     # 단위 방향벡터
#     ux = dx / d
#     uy = dy / d

#     # SVG 사양: large_arc_flag != sweep_flag 이면 candidate1, 아니면 candidate2
#     # candidate1: center = mid + (-uy, ux)*h
#     # candidate2: center = mid + (uy, -ux)*h
#     if large_arc_flag != sweep_flag:
#         cx = mid_x + (-uy)*h
#         cy = mid_y + (ux)*h
#     else:
#         cx = mid_x + (uy)*h
#         cy = mid_y + (-ux)*h

#     # 3) 시작각, 끝각
#     theta_start = math.atan2(start_y - cy, start_x - cx)
#     theta_end   = math.atan2(end_y - cy, end_x - cx)

#     # 아크의 진행각
#     delta_theta = theta_end - theta_start

#     # sweep_flag 적용
#     if sweep_flag:
#         if delta_theta < 0:
#             delta_theta += 2*math.pi
#     else:
#         if delta_theta > 0:
#             delta_theta -= 2*math.pi

#     # large_arc_flag 적용
#     if large_arc_flag and abs(delta_theta) < math.pi:
#         if delta_theta > 0:
#             delta_theta -= 2*math.pi
#         else:
#             delta_theta += 2*math.pi
#     elif not large_arc_flag and abs(delta_theta) > math.pi:
#         if delta_theta > 0:
#             delta_theta -= 2*math.pi
#         else:
#             delta_theta += 2*math.pi

#     # 4) 하나의 Cubic Bezier로 근사 (Spencer Mortensen 공식)
#     # P0, P3
#     P0 = (cx + r*math.cos(theta_start), cy + r*math.sin(theta_start))
#     P3 = (cx + r*math.cos(theta_start + delta_theta),
#           cy + r*math.sin(theta_start + delta_theta))

#     # k = 4/3 * tan((delta_theta)/4)
#     k = (4.0/3.0) * math.tan(delta_theta/4.0)

#     # P1, P2
#     # P1 = P0 + k*r*(-sin(theta_start), cos(theta_start))
#     P1 = (P0[0] - k*r*math.sin(theta_start),
#           P0[1] + k*r*math.cos(theta_start))

#     # P2 = P3 + k*r*(sin(theta_end), -cos(theta_end))
#     # 끝각 = theta_start + delta_theta
#     the_end = theta_start + delta_theta
#     P2 = (P3[0] + k*r*math.sin(the_end),
#           P3[1] - k*r*math.cos(the_end))

#     return (P0, P1, P2, P3)

# # start_x = 0.0
# # start_y = 61.33357498201926
# # end_x   = 23.36159451337427
# # end_y   = 61.33357498201926
# # r_value = 11.745690574779847
# # rotation_angle = 0
# # large_arc_flag = False
# # sweep_flag     = False

# # # 단 하나의 Cubic Bézier로 근사
# # (P0, P1, P2, P3) = single_arc_to_cubic_bezier(
# #     start_x, start_y,
# #     end_x,   end_y,
# #     r_value,
# #     rotation_angle,
# #     large_arc_flag,
# #     sweep_flag
# # )
# # print(P1[0], P1[1])

# %%
SPEC_FILE_PATH
# Out:
# '/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_0/default_body/rand_023FMIGQK0/rand_023FMIGQK0_specification.json'

# %%
# 필요한 함수 실행
import pandas as pd
from svgpathtools import Path, Line, QuadraticBezier, CubicBezier, Arc
import os
import random
import string
import json

def load_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

def euler_angles_to_rotation_matrix(euler_angles):
    """
    Convert Euler angles to a rotation matrix.
    
    Parameters:
    euler_angles (tuple or list): A tuple or list of three angles (roll, pitch, yaw) in radians.
    
    Returns:
    np.ndarray: A 3x3 rotation matrix.
    """
    roll, pitch, yaw = euler_angles

    # Compute individual rotation matrices
    R_x = np.array([
        [1, 0, 0],
        [0, np.cos(roll), -np.sin(roll)],
        [0, np.sin(roll), np.cos(roll)]
    ])

    R_y = np.array([
        [np.cos(pitch), 0, np.sin(pitch)],
        [0, 1, 0],
        [-np.sin(pitch), 0, np.cos(pitch)]
    ])

    R_z = np.array([
        [np.cos(yaw), -np.sin(yaw), 0],
        [np.sin(yaw), np.cos(yaw), 0],
        [0, 0, 1]
    ])

    # Combine the rotation matrices
    R = np.dot(R_z, np.dot(R_y, R_x))

    return R

def calculate_center_point(panel_name, spec, panel_svg_path_dict):
    vertices_from_spec = np.asarray(spec['pattern']['panels'][panel_name]['vertices'])    
    offset = np.min(vertices_from_spec * np.array([1, -1]), axis=0)

    euler_angles = spec['pattern']['panels'][panel_name]['rotation']
    translation = spec['pattern']['panels'][panel_name]['translation']
    rotation_matrix = euler_angles_to_rotation_matrix(euler_angles)

    path = panel_svg_path_dict[panel_name][0]
    
    x1, x2, y1, y2 = path.bbox()
    xm = (x1 + x2) / 2
    ym = (y1 + y2) / 2 
    
    bbox_center = np.array([xm, ym])
    bbox_center = (bbox_center + offset) * np.array([1, -1])
    
    batch_point = np.array([
        bbox_center[0], bbox_center[1], 1
    ]) @ rotation_matrix.T + translation
    #print(panel_name, batch_point) 
    return batch_point.reshape(1, -1)
    # batch_point_list.append(batch_point.reshape(1, -1))

def  matching_point(target_point):
# 모든 batch_point들과 target_point 간의 거리(L2 norm) 계산
    keys = list(batch_points.keys())  # batch_point의 key 목록
    values = np.array(list(batch_points.values()))  # value를 numpy 배열로 변환

    # L2 거리 계산 (유클리드 거리)
    distances = np.linalg.norm(values - target_point, axis=1)

    # 가장 가까운 key 찾기
    closest_index = np.argmin(distances)  # 최소 거리의 인덱스
    closest_key = keys[closest_index]  # 해당 인덱스의 key 가져오기

    #print(f"가장 가까운 batch_point: {closest_key}")
    
    return closest_key    



def process_path_data(data):
    """
    주어진 Path 데이터를 DataFrame으로 처리.
    - 요소 타입 변환 (QuadraticBezier -> Bezier Curve, Line -> Straight)
    - start, control, control1, control2, end, radius의 실수부/허수부를 x, y로 분리
    - 복소수 열 제거
    
    Args
        data (tuple): Path 객체와 속성 정보가 포함된 데이터
    
    Returns:
        pd.DataFrame: 처리된 데이터프레임
    """
    rows = []
    # Path 내부 요소 순회
    for element in data[0]:
        row = {
            "type": type(element).__name__,  # 요소 타입
            "start": getattr(element, "start", None),
            "controla": getattr(element, "control", None),
            "controlb": getattr(element, "control", None),
            "control1": getattr(element, "control1", None),
            "control2": getattr(element, "control2", None),
            "end": getattr(element, "end", None),
            "radius": getattr(element, "radius", None),
            "rotation": getattr(element, "rotation", None),
            "large_arc": getattr(element, "large_arc", None),
            "sweep": getattr(element, "sweep", None),
        }
        rows.append(row)
    
    # DataFrame 생성
    df = pd.DataFrame(rows)
    
    # type 열의 값을 변경하기 위한 매핑 사전
    type_mapping = {
        "QuadraticBezier": "Bezier Curve",
        "CubicBezier": "Bezier Curve",
        "Line": "Straight",
        "Arc": "Arc", #임의로 바꿈    
    }
    
    # type 열 값 변경
    df["type"] = df["type"].map(type_mapping).fillna(df["type"])
    
    # TODO: 2024.01.16 이후 Arc에 대한 정보에 대해 Bezier Curve로 변환예정.
    # -> 일단 되게 끔 하는게 목표.
    # 대상 열 목록
    coordinate_columns = ["start",  "controla", "controlb", "control1", "control2",  "end"] 
    ### 여기서 ARC 데이터 처리를 해줘야함.
    
    # 실수부와 허수부를 분리하여 새로운 열로 추가하는 함수
    def extract_coordinates(df, columns):
        for col in columns:
            df[f"{col}_x"] = df[col].apply(lambda z: z.real if isinstance(z, complex) else None)
            df[f"{col}_y"] = df[col].apply(lambda z: z.imag if isinstance(z, complex) else None)
        # TODO: x, y 좌표를 상하 반전
        # minimize
        max_y = df[['start_y', 'controla_y', 'controlb_y', 'control1_y', 'control2_y', 'end_y']].max().max()
        min_y = df[['start_y', 'controla_y', 'controlb_y', 'control1_y', 'control2_y', 'end_y']].min().min()
        stand_y = (max_y + min_y)
        #잠만대기기기한부분 20250208
        for col in columns: 
            df[f"{col}_y"] = (stand_y - df[f"{col}_y"]) * (8.5) #TODO: 01.17 scaling까지 
            df[f"{col}_x"] = df[f"{col}_x"] * (8.5)#TODO: scaling까지 
        df['controlb_x'] = df['controla_x'].round(4) # TODO: ontrolb_x 에 round
        df[f"radius"] = df[f"radius"] * (8.5)
        #TODO: 여기까지
        return df
    
    # 실수부와 허수부를 분리하여 데이터프레임에 추가
    df = extract_coordinates(df, coordinate_columns)
    
    # 기존 열 중 복소수 값을 제거
    df = df.drop(columns=coordinate_columns)
    
    return df

def calculate_edge_length(edge):
    """
    각 엣지의 길이를 계산. QuadraticBezier의 경우 CubicBezier처럼 처리. 
    """
    if isinstance(edge, Line):
        return abs(edge.end - edge.start)
    elif isinstance(edge, QuadraticBezier):
        # QuadraticBezier -> CubicBezier 변환
        # 기존 컨트롤 포인트
        control1 = edge.control
        
        # 새로운 컨트롤 포인트 추가
        control2 = complex(round(control1.real, 4), control1.imag)  # x좌표 소수점 4자리로 변경
        # QuadraticBezier -> CubicBezier 변환
        cubic_edge = CubicBezier(
            start=edge.start,
            control1=control1,
            control2=control2,
            end=edge.end
        )
        # CubicBezier 길이 계산
        return cubic_edge.length()
    elif isinstance(edge, CubicBezier):
        return edge.length()
    elif isinstance(edge, Arc):
        return edge.length()
    else:
        raise ValueError(f"Unsupported edge type: {type(edge)}")

def calculate_fstart_fend(path, panel_name):
    """
    전체 엣지에 대해 fstart와 fend를 계산.
    """
    total_length = sum(calculate_edge_length(edge) for edge in path)
    fstart = 0.0
    results = []

    for idx, edge in enumerate(path):  # enumerate를 사용하여 번호 부여
        edge_length = calculate_edge_length(edge) # TODO: name 넣어봄 01.19.17:00
        fend = fstart + (edge_length / total_length)
        results.append({
            "edge_id": idx,  # 엣지 번호
            "edge": str(edge),  # Edge를 문자열로 변환하여 저장
            "fstart": round(fstart, 6),
            "fend": round(fend, 6)
        })
        fstart = fend

    return results

# 패널 이름에 따라 데이터프레임 처리
def process_negative_columns(panel_names, panel_dataframes):
    # 패널 이름이 '_back', '_b', '_btorso'로 끝나는 경우
    if '_back' in panel_names or '_b' in panel_names or '_btorso' in panel_names or "_b_l" in panel_names or "_b_r" in panel_names:
        #print(f"Processing panel: {panel_names}")  # 디버깅 출력
        # 해당 데이터프레임의 '_x'로 끝나는 열 처리
        df = panel_dataframes
        df_columns = df.columns  # 데이터프레임 열 이름 가져오기
        

        # TODO: 20240123 15:30 그냥 해봄            
        for col in df_columns:
            if col.endswith('_x'):  # '_x'로 끝나는 열 확인
                # df[col] = stand_x - df[col]
                df[col] = df[col] * -1  # 열 값에 음수 곱하기
                # print(df[col])
    else:
        #print(f"Skipping panel: {panel_names}")
        pass
    return panel_dataframes

def convert_stitch_dict(stitch_dict_info, panel_index_mapping_info):
    new_stitch_dict = {}
    #print(panel_index_mapping)
    #print(stitch_dict.items())
    # print(stitch_dict_info.items())
    # print(999)
    for key, value in stitch_dict_info.items():
        filtered_list = []
        for stitch in value:
            if isinstance(stitch, dict) and 'panel' in stitch and 'edge' in stitch:
                filtered_list.append({
                    'panel': panel_index_mapping_info[stitch['panel']],
                    'edge': stitch['edge']
                })
            else:
                # dict가 아니거나 panel/edge 키가 없으면 무시
                pass

        new_stitch_dict[key] = filtered_list
        # 바꾸기 전에쓰던것.
        # new_stitch_dict[key] = [
        #     {'panel': panel_index_mapping_info[stitch['panel']], 'edge': stitch['edge']} for stitch in value
        # ]
    value_stack = []
    for value in new_stitch_dict.values():
        # dictionary stack
        for value in value:
            value_stack.append(value)     
    return value_stack

# 통합할때 추가하는 방법. (2024.02.04 작성)
def unify_clo_json_data(Clo_json_path, Clo_json_path_to_add):
    with open(Clo_json_path, 'r') as file:
        json_data = json.load(file)
    with open(Clo_json_path_to_add, 'r') as file:
        json_data_to_add = json.load(file)
    
    # FabricList, GradingRuleTableList(제껴도됨), PatternList, SymmetricDataList(제껴도됨), InstanceDataList, SeamLinePairGroupList
    # 통합할때 추가하는 방법.
    # Fabric의 경우
    json_data['FabricList'].append(json_data_to_add['FabricList'][0])
    # Pattern의 경우
    [json_data['PatternList'].append(json_data_to_add['PatternList'][num]) for num in range(len(json_data_to_add['PatternList']))]
    # InstanceDataList의 경우
    [json_data['InstanceDataList'].append(json_data_to_add['InstanceDataList'][num]) for num in range(len(json_data_to_add['InstanceDataList']))]
    # SeamLinePairGroupList의 경우
    [json_data['SeamLinePairGroupList'].append(json_data_to_add['SeamLinePairGroupList'][num]) for num in range(len(json_data_to_add['SeamLinePairGroupList']))]
    
    return json_data
# 통합된 STITCH 추가하는 방법. (2024.02.04 작성)
def stitch_data_unify(Clo_stitch_path, Clo_stitch_path_to_add):
    with open(Clo_stitch_path, "r") as f:
        stitch_data_1 = json.load(f)
    #stitch_data_1
    with open(Clo_stitch_path_to_add, "r") as f:
        stitch_data_2 = json.load(f)
    
    max_panel_1 = max(d["panel"] for d in stitch_data_1)
    offset = max_panel_1 + 1
    for item in stitch_data_2:
        item["panel"] += offset
    garment_first_id = os.path.basename(os.path.dirname(Clo_stitch_path))
    garment_second_id = os.path.basename(os.path.dirname(Clo_stitch_path_to_add))

    return (stitch_data_1+stitch_data_2), [garment_first_id, garment_second_id]

# Unique UUID 생성
def get_unique_random_string(existing_set):
    while True:
        # 영문(대소문자) + 숫자
        candidate = ''.join(random.choices(string.ascii_letters + string.digits, k=6))
        # 중복 검사
        if candidate not in existing_set:
            existing_set.add(candidate)
            return candidate

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def svg_arc_to_center(x1, y1, x2, y2, rx, ry, phi, large_arc, sweep):
    """
    SVG의 endpoint-to-center 변환 알고리즘(회전 phi 포함)을 수행합니다.
    여기서는 phi가 0라고 가정할 수 있으므로, cos(phi)=1, sin(phi)=0를 사용합니다.
    
    반환: (cx, cy, theta_start, theta_end, delta_theta)
    """

    # phi (회전각)을 라디안으로
    phi_rad = math.radians(phi)
    
    # Step 1: 중간점과 변환된 좌표 (phi=0이면 그대로)
    dx = (x1 - x2) / 2.0
    dy = (y1 - y2) / 2.0
    # x1', y1'
    x1p = math.cos(phi_rad)*dx + math.sin(phi_rad)*dy
    y1p = -math.sin(phi_rad)*dx + math.cos(phi_rad)*dy
    
    # Step 2: rx,ry 스케일링 체크 (여기서는 필요 없으리라 가정)
    lam = (x1p**2)/(rx**2) + (y1p**2)/(ry**2)
    if lam > 1:
        scale = math.sqrt(lam)
        rx *= scale
        ry *= scale

    # Step 3: 계수 (SVG 사양에 따른)
    num = rx**2 * ry**2 - rx**2 * y1p**2 - ry**2 * x1p**2
    den = rx**2 * y1p**2 + ry**2 * x1p**2
    # 부동소수점 오차로 음수 방지
    factor = math.sqrt(max(0, num/den)) if den != 0 else 0
    # SVG 사양에 따라, large_arc와 sweep 플래그가 같으면 부호 반전

    if large_arc == sweep:
        factor = -factor
    

    # if sweep == True:
    #     sweep = False
    # else:
    #     sweep = True    
        
    cxp = factor * (rx * y1p / ry)
    cyp = factor * (-ry * x1p / rx)

    # Step 4: 원래 좌표계로 복원 (phi=0이면 회전 없이 중간점에 더함)
    mid_x = (x1 + x2) / 2.0
    mid_y = (y1 + y2) / 2.0
    cx = math.cos(phi_rad)*cxp - math.sin(phi_rad)*cyp + mid_x
    cy = math.sin(phi_rad)*cxp + math.cos(phi_rad)*cyp + mid_y

    # Step 5: 시작각과 끝각 (원 중심 기준)
    theta_start = math.atan2(y1 - cy, x1 - cx)
    theta_end   = math.atan2(y2 - cy, x2 - cx)
    
    # Step 6: 아크의 진행각 delta_theta 결정 (SVG 사양)
    delta_theta = theta_end - theta_start
    if sweep:
        if delta_theta < 0:
            delta_theta += 2*math.pi
    else:
        if delta_theta > 0:
            delta_theta -= 2*math.pi
    
    # 대개 추가 보정은 필요하나, 여기서는 플래그에 따른 delta_theta만 사용
    return cx, cy, theta_start, theta_end, delta_theta

def reflect_two_points_across_line(P0, P1, P2, P3):
    """
    직선 P0-P3에 대해,
    점 P1과 P2를 '동시에' 대칭시킨 (P1', P2')를 반환한다.
    
    각 인자는 (x, y) 형태의 튜플 또는 리스트라고 가정.
    """
    P0 = np.array(P0, dtype=float)    
    P1 = np.array(P1, dtype=float)
    P2 = np.array(P2, dtype=float)
    P3 = np.array(P3, dtype=float)
    # 직선 방향벡터
    v = P3 - P0
    # 내적 (v·v)
    vdotv = v.dot(v)
    
    # 만약 P0와 P3가 같다면 반사 불가능 → 그냥 원래 점 반환하거나 예외 처리
    if abs(vdotv) < 1e-15:
        return (tuple(P1), tuple(P2))
    
    # ---- P1 대칭 ----
    w1 = P1 - P0
    w1dotv = w1.dot(v)
    w1_proj = (w1dotv / vdotv) * v
    w1_prime = 2 * w1_proj - w1
    P1_reflected = P0 + w1_prime  # P1'
    
    # ---- P2 대칭 ----
    w2 = P2 - P0
    w2dotv = w2.dot(v)
    w2_proj = (w2dotv / vdotv) * v
    w2_prime = 2 * w2_proj - w2
    P2_reflected = P0 + w2_prime  # P2'
    
    return tuple(P1_reflected), tuple(P2_reflected)

def single_arc_to_cubic_bezier(x1, y1, x2, y2, rx, ry, rotation, large_arc, sweep):
    """
    주어진 ARC 정보를 기반으로 단일 Cubic Bézier 곡선으로 근사합니다.
    회전(rotation)은 도 단위이며, 여기서는 rotation=0가 주어졌습니다.
    
    반환: (P0, P1, P2, P3), 그리고 (cx, cy, theta_start, theta_end, delta_theta)
    """
    #이렇게하면 뒤만 이상해짐
    # if sweep == True:
    #     sweep = False
    # else:
    #     sweep = True
        
    cx, cy, theta_start, theta_end, delta_theta = svg_arc_to_center(x1, y1, x2, y2, rx, ry, rotation, large_arc, sweep)
    
    # 엔드포인트들
    P0 = (cx + rx * math.cos(theta_start), cy + ry * math.sin(theta_start))
    P3 = (cx + rx * math.cos(theta_end),   cy + ry * math.sin(theta_end))
    
    # Cubic Bézier 공식: k = (4/3)*tan(delta_theta/4)
    k = (4.0/3.0) * math.tan(delta_theta/4.0)
    
    # 컨트롤 포인트
    P1 = (P0[0] - k * rx * math.sin(theta_start),
          P0[1] + k * ry * math.cos(theta_start))
    P2 = (P3[0] + k * rx * math.sin(theta_end),
          P3[1] - k * ry * math.cos(theta_end))
    
    #P1_inverse, P2_inverse = reflect_two_points_across_line(P0, P1, P2, P3)
    return (P0, P1, P2, P3)

# --------------------------------------------------------------------
# 주어진 ARC 정보
# Arc(start=(13.019250000000005+0j), radius=(13.896131794946111+13.896131794946111j),
#     rotation=0, large_arc=False, sweep=False, end=(23.83805+5.175120074823674j))

# %%
batch_points = {
"Arm_Back_1_L" : [ 20.4240,  132.30371, -15.25501],
"Arm_Back_2_L" : [ 25.4240,  127.80371, -15.25501],
"Arm_Back_3_L" : [ 30.4240,  123.30371, -15.25501],
"Arm_Back_4_L" : [ 35.4240,  118.80371, -15.25501],
"Arm_Back_5_L" : [ 40.4240,  114.30371, -15.25501],
"Arm_Back_6_L" : [ 45.4240,  109.80371, -15.25501],
"Arm_Back_7_L" : [ 50.4240,  105.30371, -15.25501],
"Arm_Back_8_L" : [ 55.4240,  100.80371, -15.25501],
"Arm_Back_1_R" : [ -20.4240,  132.30371, -15.25501],
"Arm_Back_2_R" : [ -25.4240,  127.80371, -15.25501],
"Arm_Back_3_R" : [ -30.4240,  123.30371, -15.25501],
"Arm_Back_4_R" : [ -35.4240,  118.80371, -15.25501],
"Arm_Back_5_R" : [ -40.4240,  114.30371, -15.25501],
"Arm_Back_6_R" : [ -45.4240,  109.80371, -15.25501],
"Arm_Back_7_R" : [ -50.4240,  105.30371, -15.25501],
"Arm_Back_8_R" : [ -55.4240,  100.80371, -15.25501],
# Mid 일단 안씀.
# "Arm_Mid_1_L" :  [ 20.4240,  138.30371, -1.300],
# "Arm_Mid_2_L" :  [ 25.4240,  133.80371, -1.000],
# "Arm_Mid_3_L" :  [ 30.4240,  129.30371, -0.7000],
# "Arm_Mid_4_L" :  [ 35.4240,  124.80371, -0.4000],
# "Arm_Mid_5_L" :  [ 40.4240,  120.30371, -0.1000],
# "Arm_Mid_6_L" :  [ 45.4240,  115.80371,  0.2000],
# "Arm_Mid_7_L" :  [ 50.4240,  111.30371,  0.5000],
# "Arm_Mid_8_L" :  [ 55.4240,  106.80371,  0.8000],
# "Arm_Mid_1_R" : [ -20.4240,  138.30371, -1.300],
# "Arm_Mid_2_R" : [ -25.4240,  133.80371, -1.000],
# "Arm_Mid_3_R" : [ -30.4240,  129.30371, -0.7000],
# "Arm_Mid_4_R" : [ -35.4240,  124.80371, -0.4000],
# "Arm_Mid_5_R" : [ -40.4240,  120.30371, -0.1000],
# "Arm_Mid_6_R" : [ -45.4240,  115.80371,  0.2000],
# "Arm_Mid_7_R" : [ -50.4240,  111.30371,  0.5000],
# "Arm_Mid_8_R" : [ -55.4240,  106.80371,  0.8000],
"Arm_Front_1_L" : [ 20.4240,  132.30371, 15.25501],
"Arm_Front_2_L" : [ 25.4240,  127.80371, 15.25501],
"Arm_Front_3_L" : [ 30.4240,  123.30371, 15.25501],
"Arm_Front_4_L" : [ 35.4240,  118.80371, 15.25501],
"Arm_Front_5_L" : [ 40.4240,  114.30371, 15.25501],
"Arm_Front_6_L" : [ 45.4240,  109.80371, 15.25501],
"Arm_Front_7_L" : [ 50.4240,  105.30371, 15.25501],
"Arm_Front_8_L" : [ 55.4240,  100.80371, 15.25501],
"Arm_Front_1_R" : [ -20.4240,  132.30371, 15.25501],
"Arm_Front_2_R" : [ -25.4240,  127.80371, 15.25501],
"Arm_Front_3_R" : [ -30.4240,  123.30371, 15.25501],
"Arm_Front_4_R" : [ -35.4240,  118.80371, 15.25501],
"Arm_Front_5_R" : [ -40.4240,  114.30371, 15.25501],
"Arm_Front_6_R" : [ -45.4240,  109.80371, 15.25501],
"Arm_Front_7_R" : [ -50.4240,  105.30371, 15.25501],
"Arm_Front_8_R" : [ -55.4240,  100.80371, 15.25501],
"Body_Front_Center_1" :[  0., 142.30371, 15.25501],
"Body_Front_Center_2" : [  0., 135.30371, 15.25501],
"Body_Front_Center_3" : [  0., 128.30371, 15.25501],
"Body_Front_Center_4" : [  0., 121.30371, 15.25501],
"Body_Front_Center_5" : [  0., 114.30371, 15.25501],
"Body_Front_Center_6" : [  0., 107.30371, 15.25501],
"Body_Front_Center_7" : [  0., 100.30371, 15.25501],
"Body_Front_Center_8" : [  0., 93.30371, 15.25501],
"Body_Front_Center_9" : [  0., 79.30371, 15.25501],
"Body_Back_Center_1" : [  0., 142.30371,-15.25501],
"Body_Back_Center_2" : [  0., 135.30371,-15.25501],
"Body_Back_Center_3" : [  0., 128.30371,-15.25501],
"Body_Back_Center_4" : [  0., 121.30371,-15.25501],
"Body_Back_Center_5" : [  0., 114.30371,-15.25501],
"Body_Back_Center_6" : [  0., 107.30371,-15.25501],
"Body_Back_Center_7" : [  0., 100.30371,-15.25501],
"Body_Back_Center_8" : [  0., 93.30371, -15.25501],
"Body_Back_Center_9" : [  0., 86.30371, -15.25501],
"Body_Back_Center_10": [  0., 75.30371, -15.25501],
"Body_Front_1_R" : [ -11.86359, 142.30371,   15.25501],
"Body_Front_2_R" : [ -11.86359, 135.30371,   15.25501],
"Body_Front_3_R" : [ -11.86359, 128.30371,   15.25501],
"Body_Front_4_R" : [ -11.86359, 121.30371,   15.25501],
"Body_Front_5_R" : [ -11.86359, 114.30371,   15.25501],
"Body_Front_6_R" : [ -11.86359, 107.30371,   15.25501],
"Body_Front_7_R" : [ -11.86359, 100.30371,   15.25501],
#"Body_Front_8_R" : [ -11.86359,  93.30371,   15.25501],
"Body_Front_1_L" : [ 11.86359, 142.30371,   15.25501],
"Body_Front_2_L" : [ 11.86359, 135.30371,   15.25501],
"Body_Front_3_L" : [ 11.86359, 128.30371,   15.25501],
"Body_Front_4_L" : [ 11.86359, 121.30371,   15.25501],
"Body_Front_5_L" : [ 11.86359, 114.30371,   15.25501],
"Body_Front_6_L" : [ 11.86359, 107.30371,   15.25501],
"Body_Front_7_L" : [ 11.86359, 100.30371,   15.25501],
#"Body_Front_8_L" : [ 11.86359,  93.30371,   15.25501],
"Body_Back_1_R" :[ -11.86359, 142.30371,   -15.25501],
"Body_Back_2_R" :[ -11.86359, 135.30371,   -15.25501],
"Body_Back_3_R" :[ -11.86359, 128.30371,   -15.25501],
"Body_Back_4_R" :[ -11.86359, 121.30371,   -15.25501],
"Body_Back_5_R" :[ -11.86359, 114.30371,   -15.25501],
"Body_Back_6_R" :[ -11.86359, 107.30371,   -15.25501],
"Body_Back_7_R" :[ -11.86359, 100.30371,   -15.25501],
"Body_Back_1_L" :[ 11.86359, 142.30371,   -15.25501],
"Body_Back_2_L" :[ 11.86359, 135.30371,   -15.25501],
"Body_Back_3_L" :[ 11.86359, 128.30371,   -15.25501],
"Body_Back_4_L" :[ 11.86359, 121.30371,   -15.25501],
"Body_Back_5_L" :[ 11.86359, 114.30371,   -15.25501],
"Body_Back_6_L" :[ 11.86359, 107.30371,   -15.25501],
"Body_Back_7_L" :[ 11.86359, 100.30371,   -15.25501],
"Leg_Front_1_L" : [ 9.86359, 78.30371,  15.25501], 
"Leg_Front_2_L" : [ 9.86359, 68.30371,  15.25501],
"Leg_Front_3_L" : [ 9.86359, 58.30371,  15.25501],
"Leg_Front_1_R" :[ -9.86359, 78.30371,  15.25501], 
"Leg_Front_2_R" :[ -9.86359, 68.30371,  15.25501],
"Leg_Front_3_R" :[ -9.86359, 58.30371,  15.25501], 
"Leg_Back_1_L" :  [ 9.86359, 78.30371,  -15.25501], 
"Leg_Back_2_L" :  [ 9.86359, 68.30371,  -15.25501],
"Leg_Back_3_L" :  [ 9.86359, 58.30371,  -15.25501],
"Leg_Back_1_R" : [ -9.86359, 78.30371,  -15.25501], 
"Leg_Back_2_R" : [ -9.86359, 68.30371,  -15.25501],
"Leg_Back_3_R" : [ -9.86359, 58.30371,  -15.25501],
"Leg_Front_Mid_1" :[-13.86359, 54.30371, 15.25501],
#TODO: 얘 보다는 skirt_front_mid가 좋음"Leg_Front_Mid_2" :[0, 54.30371, 15.25501],
"Leg_Front_Mid_3" :[13.86359, 54.30371, 15.25501],
"Leg_Back_Mid_1" :[13.86359, 54.30371, -15.25501],
#TODO: 얘 보다는 skirt_back_mid가 좋음"Leg_Back_Mid_2" :[0, 54.30371, -15.25501],
"Leg_Back_Mid_3" :[-13.86359, 54.30371, -15.25501],
"Skirt_Front_Center" : [0, 54.30371, 15.25501],#[0, 56.30371, 15.25501],
"Skirt_Front_Center_1":[0, 50.30371, 15.25501],
"Skirt_Front_Center_2":[0, 42.30371, 15.25501],
"Skirt_Front_Center_3":[0, 36.30371, 15.25501],
"Skirt_Front_Center_4":[0, 30.30371, 15.25501],
"Skirt_Front_Center_5":[0, 18.30371, 15.25501],
"Skirt_Front_Center_6" : [0, 6.30371, 15.25501],
"Skirt_Back_Center" : [0, 54.30371, -15.25501],#[0, 56.30371, -15.25501],
"Skirt_Back_Center_1" :[0, 50.30371, -15.25501],
"Skirt_Back_Center_2" :[0, 42.30371, -15.25501],
"Skirt_Back_Center_3" :[0, 36.30371, -15.25501],
"Skirt_Back_Center_4" :[0, 30.30371, -15.25501],
"Skirt_Back_Center_5" :[0, 18.30371, -15.25501],
"Skirt_Back_Center_6" :[0, 6.30371, -15.25501],
"Leg_Front_Mid_L" : [9.86359, 48.30371, 15.25501], 
"Leg_Front_Mid_R" :[-9.86359, 48.30371, 15.25501], 
"Leg_Back_Mid_L" :[9.86359, 48.30371, -15.25501],
"Leg_Back_Mid_R" :[-9.86359, 48.30371, -15.25501],
"Shoulder_Top_L" : [  11.424, 142.30371, 0.],
"Shoulder_Top_R": [  -11.424, 142.30371, 0.],
"Neck_L" :[  5.424, 149.30371, 1.],
"Neck_R" :[  -5.424, 149.30371, 1.],
"Neck_Back_Center" :[  0., 149.30371, -15.25501],
"Neck_Front_Center" :[  0., 145.30371, 15.25501],
"Head_L" : [ 10., 160.30371, 0],
"Head_R" : [ -10., 160.30371, 0],
"Head_Back_L" : [ 7., 160.30371, -15.25501],
"Head_Back_R" : [ -7., 160.30371, -15.25501],
"Head_Back_Center" :[ 0., 160.30371, -15.25501],
"Head_Front_Center" : [ 0., 160.30371, 15.25501],
"Head_Top_L" :[ 5., 172.30371, 0],
"Head_Top_R" :[ -5., 172.30371, 0],
"Head_Top_Center" : [ 0., 172.30371, 0],
"Leg_Front_Point_1" :[18.86359, 22.30371, 15.25501],
"Leg_Front_Point_2" :[11.86359, 22.30371, 15.25501],
"Leg_Front_Point_3" :[4.86359, 22.30371, 15.25501],
"Leg_Front_Point_4" :[-4.86359, 22.30371, 15.25501],
"Leg_Front_Point_5" :[-11.86359, 22.30371, 15.25501],
"Leg_Front_Point_6" :[-18.86359, 22.30371, 15.25501],
"Leg_Back_Point_1" :[18.86359, 22.30371, -15.25501],
"Leg_Back_Point_2" :[11.86359, 22.30371, -15.25501],
"Leg_Back_Point_3" :[4.86359, 22.30371, -15.25501],
"Leg_Back_Point_4" :[-4.86359, 22.30371, -15.25501],
"Leg_Back_Point_5" :[-11.86359, 22.30371, -15.25501], 
"Leg_Back_Point_6" :[-18.86359, 22.30371, -15.25501],
}
for key, value in batch_points.items():
    batch_points[key] = [value[0], value[1] -10, value[2]]

# %%
PROJECT_ROOT_PATH = "/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/"
GARMENT_ROOT_PATH = os.path.join(PROJECT_ROOT_PATH, "GarmentCodeData_v2")
BODY_ROOT_PATH = os.path.join(PROJECT_ROOT_PATH, "body_mesh")
MEAN_ALL_BODY_PATH = os.path.join(PROJECT_ROOT_PATH, "neutral_body/mean_all.obj")
# random choice two number
BODY_TYPE = "default_body"
    
default_body_mesh = trimesh.load(MEAN_ALL_BODY_PATH)

# %%
##garment_path = garment_path_list[IDX]
# garment_path = "/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_0/default_body/rand_0BD28UCVO8"
# garment_path = "/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_0/default_body/rand_0AAY3NQH8J"
# garment_path = "/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_3/default_body/rand_005ZYVMOCL"
# garment_path = "/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_0/default_body/rand_0A36YXPNV0"
##garment_id = os.path.basename(garment_path)

#SPEC_FILE_PATH = os.path.join(garment_path, f"{garment_id}_specification.json")

garment_path_list = sorted(list(filter(
    os.path.isdir,
    glob(os.path.join(GARMENT_ROOT_PATH, "*", BODY_TYPE, "*"))
)))
len(garment_path_list)
# Out:
# 132670

# %%
# single_arc_to_cubic_bezier(start_x, start_y, end_x, end_y, r,
#                                rotation_angle,
#                                large_arc_flag,
#                                sweep_flag)

# %%
garment_path_list[0]
# Out:
# '/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_0/default_body/rand_00YONAPXZE'

# %%
garment_path_list[1]
# Out:
# '/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_0/default_body/rand_023FMIGQK0'

# %%
# 루트 돌게끔.
# 여러 패널의 정보를 저장할 딕셔너리
#garment_id = os.path.basename(SPEC_FILE_PATH)

""" 원래 진행하는 부분인데 일단 일시적으로 멈춰 둠. ARC 데이터셋 함 뽑아봐야함 + ARC로 들어오는 데이터셋에 대해서 변환도 진행해야함.
# NO_ARC_PATH
json_file_path = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/garment_without_arc_list.json"

json_data = load_json_file(json_file_path)
#IDX = random.randint(0, len(json_data) - 1)
"""

#IDX = 1000

""" Arc data 일부만 되게 해볼려고 만듬.
# IDX_1 = random.randint(0, len(garment_path_list) - 1)
# IDX_2 = random.randint(0, len(garment_path_list) - 1)
#json_data = [garment_path_list[IDX_1], garment_path_list[IDX_2]]
#datt1 ="/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_0/default_body/rand_SPH85AKNMR"
#datt2 ="/media/hjp/05aba9a7-0e74-4e54-9bc9-5f11b9c4c757/GarmentCodeData/GarmentCodeData_v2/garments_5000_15/default_body/rand_285333IFRT"
#json_data = [datt1, datt2]
"""

# random Fabric UUID 생성을 위해 유니크하게.
generated = set()

#for IDX in tqdm(range(len(json_data))):
for IDX in tqdm(range(len(garment_path_list))):
    # random Fabric UUID 생성
    fabric_uuid = get_unique_random_string(generated)    
    # radnom hexa code 생성
    random_hexa_code = ''.join(random.choices('0123456789ABCDEF', k=6))
    garment_path = garment_path_list[IDX]
    path_split= garment_path.split(os.sep)
    garment_id= os.path.basename(garment_path)
    SPEC_FILE_PATH = os.path.join(garment_path,  f"{garment_id}_specification.json")
    pattern = pyg.pattern.wrappers.VisPattern(SPEC_FILE_PATH)
    drawn_pattern_list = list(map(
        lambda pannel_name : pattern._draw_a_panel(
            pannel_name, apply_transform=False, fill=True
        ),
        pattern.panel_order()
    ))

    panel_svg_path_dict = {
        panel_name : pattern._draw_a_panel(
            panel_name, apply_transform=False, fill=True
        )
        for panel_name in pattern.panel_order()
    }

    stitch_dict = {
        i : v for i, v in enumerate(pattern.pattern['stitches'])
    }

    # json의 rotation translation 추출을 위한 정보
    spec = load_json_file(SPEC_FILE_PATH)
    """
    # TODO: 2025.02.05 패널 중심점 대신 Mean Point 사용한 버전
    """
### 여기부터
    box_mesh = trimesh.load_mesh(
        os.path.join(garment_path, f"{garment_id}_boxmesh.ply"),
        process=False
    )
#    box_mesh.vertices = box_mesh.vertices / 100

    idx_convert_map = np.array(v_id_map(box_mesh.vertices))


    # Read Vertex Label
    with open(os.path.join(garment_path, f"{garment_id}_sim_segmentation.txt"), "r") as f:
        segmentation = list(map(
            lambda x : x.strip(),
            f.readlines()
        ))

    stitch_vertex_mask_dict = {}
    for k in stitch_dict.keys():
        raw_mask = list(map(
            lambda x : True if f"stitch_{k}" in x.split(",") else False,
            segmentation
        ))
        base_mask = np.array(list(map(
            lambda idx : True if raw_mask[idx] else False,
            idx_convert_map
        )))
        stitch_vertex_mask_dict[k] = base_mask


    panel_vertex_mask_dict = {}
    for k in panel_svg_path_dict.keys():
        raw_mask = list(map(
            lambda x : True if x.startswith(k) else False,
            segmentation
        ))
        panel_vertex_mask_dict[k] = np.array(list(map(
            lambda idx : True if raw_mask[idx] else False,
            idx_convert_map
        )))

    panel_center_point_dict = {}
    for k in panel_vertex_mask_dict.keys():
        panel_center_point_dict[k] = np.mean(box_mesh.vertices[panel_vertex_mask_dict[k]], axis=0)
        
### 여기까지
    panel_fstart_fend_info = {}

    # 패널 리스트 (예: pattern.panel_order())
    panel_list = pattern.panel_order()

    # 각 패널에 대해 fstart, fend 계산
    for panel_name in panel_list:
        path = panel_svg_path_dict[panel_name][0]  # 패널에 해당하는 경로 정보 가져오기
        fstart_fend_results = calculate_fstart_fend(path, panel_name) # TODO: 2024.01.19 14:33 panel_name 넣기
        panel_fstart_fend_info[panel_name] = fstart_fend_results  # 결과를 딕셔너리에 저장

    # 패널 데이터프레임 생성
    panel_dataframes = [process_path_data(drawn_pattern) for drawn_pattern in drawn_pattern_list]
    #print(panel_dataframes)
    panel_names = list(pattern.panel_order())
    #print(type(panel_dataframes))
    # 1) 'Arc' 행만 필터링
    #####잠깐ㅈ깐
    # for i, df in enumerate(panel_dataframes):
    #     print(i, df)
    #     arc_rows = df.loc[df["type"] == "Arc"]
    #     # 2) 'Arc' 행이 있는지 체크
    #     if arc_rows.empty:
    #         pass
    #     else:
    #         # 'Arc' 행이 있으면 반복문으로 처리
    #         for idx, row in arc_rows.iterrows():
    #             radius    = row["radius"].real
    #             rotation  = row["rotation"]
    #             large_arc = row["large_arc"]
    #             sweep     = row["sweep"]
    #             start_x   = row["start_x"]
    #             start_y   = row["start_y"]
    #             end_x     = row["end_x"]
    #             end_y     = row["end_y"]

    #             # AAA() 함수 호출
    #             start, control1, control2, end = single_arc_to_cubic_bezier(start_x, start_y, 
    #                                     end_x, end_y, 
    #                                     radius, rotation,
    #                                     large_arc, sweep)
    #             # 결과값을 4개의 열에 저장 (원하는 열 이름으로 수정)
    #             df.at[idx, "type"] = "Bezier Curve"
    #             df.at[idx, "control1_x"] = control1[0]
    #             df.at[idx, "control1_y"] = control1[1]
    #             df.at[idx, "control2_x"] = control2[0]
    #             df.at[idx, "control2_y"] = control2[1]

    # Initialize the top-level JSON structure
    garment_data = {
        "FabricList": [],
        "GradingRuleTableList": [],
        "PatternList": [],
        "SymmetricDataList": [],
        "InstanceDataList": [],
        "SeamLinePairGroupList": [],
    }

    # Process each panel
    for panel_name, df in zip(panel_names, panel_dataframes):
        # Initialize JSON structure for the panel
        # 좀 수정 좀 해봄.
        #panel_dataframes = process_negative_columns(panel_name, df)
        arc_rows = df.loc[df["type"] == "Arc"]
        # 2) 'Arc' 행이 있는지 체크
        if arc_rows.empty:
            pass
        else:
            # 'Arc' 행이 있으면 반복문으로 처리
            for idx, row in arc_rows.iterrows():
                rx    = row["radius"].real
                ry    = row["radius"].imag
                rotation  = row["rotation"]
                large_arc = row["large_arc"]
                sweep     = row["sweep"]
                start_x   = row["start_x"] 
                start_y   = row["start_y"] 
                end_x     = row["end_x"] 
                end_y     = row["end_y"] 

                # AAA() 함수 호출
                start, control1, control2, end = single_arc_to_cubic_bezier(start_x, start_y, 
                                        end_x, end_y, 
                                        rx, ry,
                                        rotation,
                                        large_arc, sweep)
                # ARC인데 back인 패널의 행에 대해서만
                #print(start, control1, control2, end)
                control_1, control_2 = reflect_two_points_across_line(start, control1, control2, end)
                #print(df)
                
                df.at[idx, "control1_x"] = control_1[0] 
                df.at[idx, "control1_y"] = control_1[1] 
                df.at[idx, "control2_x"] = control_2[0] 
                df.at[idx, "control2_y"] = control_2[1] 
                df.at[idx, "type"] = "Bezier Curve"
        ##잠만대기기기기
        #panel_dataframes
                # 임시.                    
                # if '_back' in panel_name or '_b' in panel_name or '_btorso' in panel_name or "_b_l" in panel_name or "_b_r" in panel_name:
                #     control1, control2 = reflect_two_points_across_line(start, control1, control2, end)
                #     df.at[idx, "type"] = "Bezier Curve"
                #     df.at[idx, "control1_x"] = control1[0]
                #     df.at[idx, "control1_y"] = control1[1]
                #     df.at[idx, "control2_x"] = control2[0]
                #     df.at[idx, "control2_y"] = control2[1]                    
                # # 결과값을 4개의 열에 저장 (원하는 열 이름으로 수정)
                # else:   
                #     df.at[idx, "type"] = "Bezier Curve"
                #     df.at[idx, "control1_x"] = control1[0]
                #     df.at[idx, "control1_y"] = control1[1]
                #     df.at[idx, "control2_x"] = control2[0]
                #     df.at[idx, "control2_y"] = control2[1]

                                    
        panel_dataframes = process_negative_columns(panel_name, df)                        
        #panel_center_point = calculate_center_point(panel_name, spec, panel_svg_path_dict)
        #print(f"{panel_name} 의 중심점 좌표 : {panel_center_point}")
        ### panel_center_point_dict의 평균점 좌표 사용해서 batch_point 계산
        #print(panel_dataframes)
        panel_batch_point = matching_point(panel_center_point_dict[panel_name]) # batch point 이름 받기
        panel_data = {
            "Name": f"{garment_id}_{panel_name}", # garment_id 추가함.
            "fGrainlineAngle": 0.0,
            "ID": f"{garment_id}_{panel_name}", # garment_id 추가함.
            "strSuperImposeSide": "None",
            "CurrentFabricUUID": fabric_uuid,
            "IsClosed": False,
            "InternalLineList": [],
            "ButtonHeadList": [],
            "ButtonHoleList": [],
            "AnnotationList": [],
            "NotchList": [],
            "IsHalfSymmetric": False,
            "ShapeInfo": {
                "IsSlashed": False,
                "LineList": [],
                "HalfSymmetryPointIDMap": {},
                "HalfSymmetryLineIDMap": {}
            },
            "ArrangementPointDataMap": {
                    "PointName": panel_batch_point,
                    "fOffSetX": 0.0,
                    "fOffSetY": 0.05,
                    "fAngle": 180.0
            }
        }
        # InstanceDataList에 json에 추가
        instance_data = {
            "OriginPatternID": panel_name,  # 패널 이름을 OriginPatternID로 사용
            "InstancePatternIDArray": []   # 빈 리스트로 추가
        }
        garment_data["InstanceDataList"].append(instance_data)
        # 패널별 좌표 ID 초기화
        coordinate_id_map = {}
        point_counter = 0  # 패널 내 좌표 카운터

        # Generate LineList and PointList for the panel
        for edge_idx, row in df.iterrows():
            line_id = f"{panel_name}_edge_{edge_idx}"
            point_list = []
            columns_x = [col for col in row.index if col.endswith('_x')]
            columns_y = [col for col in row.index if col.endswith('_y')]
            
            if row["type"] == "Bezier Curve":
                row_type = ["Straight", "Bezier Curve", "Bezier Curve", "Straight"]
                idx = 0
                for col_x, col_y in zip(columns_x, columns_y):  # Skip 'type' and go by pairs
                    x, y = row[col_x], row[col_y]
                    if not (pd.isna(x) or pd.isna(y)):#TODO: or math.isclose(x, 0.0) and math.isclose(y, 0.0) ):
                        # 좌표에 대해 새로운 ID 생성 (패널 내에서만)
                        key = (x, y)
                        if key not in coordinate_id_map:
                            coordinate_id_map[key] = f"{panel_name}_point_{point_counter}"
                            point_counter += 1
                        point_id = coordinate_id_map[key]
                        
                        point_list.append({
                            "ID": point_id, 
                            "PointType": row_type[idx],
                            "Position": {"x": x, "y": y},
                            "GradingRuleID": -1
                        })
                        idx +=1 
            # TODO: Arc 타입에 대해 베지어로 변환하여 Json에 넣는 작업.
            # 2025.02.07 18:05 에 수정 시작
            # elif row["type"] == "Arc":
            #     arc_bezier = arc_to_bezier(row)
            #     columns_x = [key for key in row.keys() if key.endswith('_x')]
            #     columns_y = [key for key in row.keys() if key.endswith('_y')]
            #     # 사용하지 않을 키 필터링
            #     excluded_keys = {"controla_x", "controlb_x", "controla_y", "controlb_y"}
            #     columns_x = [col for col in columns_x if col not in excluded_keys]
            #     columns_y = [col for col in columns_y if col not in excluded_keys]
            #     print(columns_x, columns_y)
                
            #     row_type = ["Straight", "Bezier Curve", "Bezier Curve", "Straight"]
            #     idx = 0
            #     for col_x, col_y in zip(columns_x, columns_y):  # Skip 'type' and go by pairs
            #         print(arc_bezier[col_x], arc_bezier[col_y])
            #         x, y = arc_bezier[col_x], arc_bezier[col_y]
            #         if not (pd.isna(x) or pd.isna(y)):#TODO: or math.isclose(x, 0.0) and math.isclose(y, 0.0) ):
            #             # 좌표에 대해 새로운 ID 생성 (패널 내에서만)
            #             key = (x, y)
            #             if key not in coordinate_id_map:
            #                 coordinate_id_map[key] = f"{panel_name}_point_{point_counter}"
            #                 point_counter += 1
            #             point_id = coordinate_id_map[key]
                        
            #             point_list.append({
            #                 "ID": point_id, 
            #                 "PointType": row_type[idx],
            #                 "Position": {"x": x, "y": y},
            #                 "GradingRuleID": -1
            #             })
            #             idx +=1          
            elif row["type"] == "Straight":
                # Iterate through columns 2 by 2 for x and y
                for col_x, col_y in zip(columns_x, columns_y):  # Skip 'type' and go by pairs
                    x, y = row[col_x], row[col_y]
                    if not (pd.isna(x) or pd.isna(y)):#TODO: or math.isclose(x, 0.0) and math.isclose(y, 0.0) ):
                        # 좌표에 대해 새로운 ID 생성 (패널 내에서만)
                        key = (x, y)
                        if key not in coordinate_id_map:
                            coordinate_id_map[key] = f"{panel_name}_point_{point_counter}"
                            point_counter += 1
                        point_id = coordinate_id_map[key]
                        
                        point_list.append({
                            "ID": point_id,
                            "PointType": row["type"],
                            "Position": {"x": x, "y": y},
                            "GradingRuleID": -1
                        })
        

            # Add Line to LineList
            line = {"ID": line_id, "PointList": point_list}
            panel_data["ShapeInfo"]["LineList"].append(line)

        # Add the panel data to the PatternList
        garment_data["PatternList"].append(panel_data)
        
    garment_data["SeamLinePairGroupList"] = []
    fabric_group = {
        "FabricName" : "Default Fabric",
        "FabricType" : "None",
        "FabricContent" : "None",
        "strBaseColorHexCode" : random_hexa_code,
        "FabricUUID" : fabric_uuid
        }
    # SeamLinePairGroupList 생성 루프
    for idx, value in enumerate(stitch_dict.values()):
        
        # "Name" 생성
        group_name = f"{garment_id}_SeamLineGroup_{idx}"

        # value에서 첫 번째와 두 번째 ShapeID 정보 추출
        first_info = value[0]
        second_info = value[1]
            
        # 정보 저장
        first_panel = first_info["panel"] # 패널 정보
        first_edge = first_info["edge"]
        first_shape_id = f"{garment_id}_{first_panel}"
        
        second_panel = second_info["panel"]
        second_edge = second_info["edge"]
        second_shape_id = f"{garment_id}_{second_panel}" #TODO: 이부분 제외 '_edge_{second_edge}"'
        
        # 첫 번째 fStart와 fEnd 추출
        first_fstart_fend = next(
            (item for item in panel_fstart_fend_info[first_panel] if item["edge_id"] == first_edge),
            None
        )
        # 두 번째 fStart와 fEnd 추출
        second_fstart_fend = next(
            (item for item in panel_fstart_fend_info[second_panel] if item["edge_id"] == second_edge),
            None
        )
        
        # first, second panel 정보 넣음
        if first_fstart_fend is not None:
            first_fstart_fend["panel"] = first_panel
        first_point = first_fstart_fend["edge"]
        
        if second_fstart_fend is not None:
            second_fstart_fend["panel"] = second_panel
        second_point = second_fstart_fend["edge"]


        
        
        first_direction = True
        second_direction = False
        
        # direction 결정 뒤에 정해 놓는 fstart, fend
        if first_direction == False:
            first_fstart, first_fend = first_fstart_fend["fend"], first_fstart_fend["fstart"]
        else:
            first_fstart, first_fend = first_fstart_fend["fstart"], first_fstart_fend["fend"]
        
        # direction 결정 뒤에 정해 놓는 fstart, fend        
        if second_direction == False:
            second_fstart, second_fend = second_fstart_fend["fend"], second_fstart_fend["fstart"]
        else:
            second_fstart, second_fend = second_fstart_fend["fstart"], second_fstart_fend["fend"]
        

        # JSON 구조 생성
        seam_line_pair_group = {
            "Name": group_name,
            "bIsTurned": False,
            "PairList": [
                {
                    "First": {
                        "ShapeID": first_shape_id,
                        "LengthParam": {
                            "fStart": first_fstart,
                            "fEnd": first_fend
                        },
                        "Direction": first_direction
                    },
                    "Second": {
                        "ShapeID": second_shape_id,
                        "LengthParam": {
                            "fStart": second_fstart,
                            "fEnd": second_fend
                        },
                        "Direction": second_direction 
                    }
                }
            ],
            "FoldData": {
                "iAngle": 180,
                "iStrength": 5
            }
        }

        # SeamLinePairGroupList에 추가
        garment_data["SeamLinePairGroupList"].append(seam_line_pair_group)

    garment_data["FabricList"].append(fabric_group)    
    
    panel_index_mapping = {name: idx for idx, name in enumerate(panel_names)}
    
    stitch_info = convert_stitch_dict(stitch_dict, panel_index_mapping)
    # CLO JSON 출력
    json_output = json.dumps(garment_data, indent=4)
    
    # CLO STITCH JSON 출력
    stitch_info_json = json.dumps(stitch_info, indent=4)
    
#    DIR = "./NO_ARC_CLO_JSON_MEAN_POINT"
    DIR = "./CLO_DATASET"
    DIR_NAME = f"{path_split[-3]}_{garment_id}"
    JSON_PATH = os.path.join(DIR, DIR_NAME)
    os.makedirs(os.path.join(DIR, DIR_NAME), exist_ok=True)
    # CLO JSON DATA FILE
    json_output_file = f"{JSON_PATH}/Clo_Garment_{path_split[-3]}_{garment_id}.json"
    # STITCH DATA FILE
    stitch_output_file = f"{JSON_PATH}/Clo_Stitch_{path_split[-3]}_{garment_id}.json"
    # print(json_output_file)
    # print(stitch_output_file)
    with open(json_output_file, "w") as file:
        file.write(json_output)
    with open(stitch_output_file, "w") as file:
        file.write(stitch_info_json)
# Out:
#   0%|          | 0/132670 [00:00<?, ?it/s]
#   0%|          | 370/132670 [02:02<13:55:37,  2.64it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   0%|          | 382/132670 [02:05<10:58:43,  3.35it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   0%|          | 462/132670 [02:32<7:34:02,  4.85it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   1%|          | 1031/132670 [05:56<16:26:52,  2.22it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   1%|          | 1229/132670 [07:06<8:49:05,  4.14it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   1%|          | 1430/132670 [08:13<22:49:15,  1.60it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   1%|          | 1438/132670 [08:16<10:54:25,  3.34it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   1%|          | 1562/132670 [08:57<13:03:04,  2.79it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   1%|          | 1651/132670 [09:27<13:48:46,  2.63it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   1%|▏         | 1841/132670 [10:32<14:05:40,  2.58it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   2%|▏         | 2101/132670 [12:02<8:59:16,  4.04it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   2%|▏         | 2118/132670 [12:10<11:07:09,  3.26it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   2%|▏         | 2232/132670 [12:48<10:14:43,  3.54it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   2%|▏         | 2571/132670 [14:36<16:19:38,  2.21it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   2%|▏         | 2585/132670 [14:41<11:39:19,  3.10it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   2%|▏         | 2956/132670 [16:48<6:32:14,  5.51it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   2%|▏         | 3315/132670 [18:46<10:09:57,  3.53it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   3%|▎         | 3564/132670 [20:03<6:20:25,  5.66it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   3%|▎         | 3692/132670 [20:46<14:52:52,  2.41it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   3%|▎         | 3932/132670 [22:04<16:35:17,  2.16it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   3%|▎         | 4017/132670 [22:32<21:44:45,  1.64it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   3%|▎         | 4345/132670 [24:28<11:22:16,  3.13it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   3%|▎         | 4430/132670 [24:57<9:05:16,  3.92it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   3%|▎         | 4509/132670 [25:24<7:57:20,  4.47it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▎         | 4701/132670 [26:27<18:01:58,  1.97it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▎         | 4829/132670 [27:10<10:38:05,  3.34it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▎         | 4853/132670 [27:20<16:35:42,  2.14it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▎         | 4970/132670 [28:05<16:46:50,  2.11it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5058/132670 [28:39<8:43:17,  4.06it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5099/132670 [28:56<8:00:32,  4.42it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5218/132670 [29:34<6:49:32,  5.19it/s] /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5245/132670 [29:42<15:51:03,  2.23it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5491/132670 [31:07<11:12:03,  3.15it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5592/132670 [31:40<12:41:07,  2.78it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5696/132670 [32:15<12:40:35,  2.78it/s]/home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3594: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/hjp/anaconda3/envs/GarmentCode/lib/python3.9/site-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#   4%|▍         | 5877/132670 [33:17<11:58:12,  2.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[100], line 80
#      78 stitch_vertex_mask_dict = {}
#      79 for k in stitch_dict.keys():
# ---> 80     raw_mask = list(map(
#      81         lambda x : True if f"stitch_{k}" in x.split(",") else False,
#      82         segmentation
#      83     ))
#      84     base_mask = np.array(list(map(
#      85         lambda idx : True if raw_mask[idx] else False,
#      86         idx_convert_map
#      87     )))
#      88     stitch_vertex_mask_dict[k] = base_mask
#
# Cell In[100], line 81, in <lambda>(x)
#      78 stitch_vertex_mask_dict = {}
#      79 for k in stitch_dict.keys():
#      80     raw_mask = list(map(
# ---> 81         lambda x : True if f"stitch_{k}" in x.split(",") else False,
#      82         segmentation
#      83     ))
#      84     base_mask = np.array(list(map(
#      85         lambda idx : True if raw_mask[idx] else False,
#      86         idx_convert_map
#      87     )))
#      88     stitch_vertex_mask_dict[k] = base_mask
#
# KeyboardInterrupt:

# %%
json_file_path = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/garment_without_arc_list.json"

def load_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

json_data = load_json_file(json_file_path)
len(json_data)
# Out:
# 30427

# %%
# len(os.listdir("./NO_ARC_CLO_JSON"))
os.listdir("./NO_ARC_CLO_JSON")[0]
# Out:
# 'Clo_Garment_garments_5000_13_rand_ZP4QMHSC6J.json'

# %%
# JSON 파일 읽고 가지고 테스트
PATH_TST = "./NO_ARC_CLO_JSON/garments_5000_0_rand_0ADI18HWRF/Clo_Garment_garments_5000_0_rand_0ADI18HWRF.json"

with open(PATH_TST, "r") as f:
    data = json.load(f)

data
# Out:
# {'FabricList': [{'FabricName': 'Default Fabric',
#    'FabricType': 'None',
#    'FabricContent': 'None',
#    'strBaseColorHexCode': '2265E2',
#    'FabricUUID': 'DWX6ey'}],
#  'GradingRuleTableList': [],
#  'PatternList': [{'Name': 'ins_skirt_back_0',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_back_0',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_back_0_edge_0',
#       'PointList': [{'ID': 'ins_skirt_back_0_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_0_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_0_edge_1',
#       'PointList': [{'ID': 'ins_skirt_back_0_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_0_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_0_edge_2',
#       'PointList': [{'ID': 'ins_skirt_back_0_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_0_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Back_Mid_3',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_front_0',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_front_0',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_front_0_edge_0',
#       'PointList': [{'ID': 'ins_skirt_front_0_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_0_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_0_edge_1',
#       'PointList': [{'ID': 'ins_skirt_front_0_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_0_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_0_edge_2',
#       'PointList': [{'ID': 'ins_skirt_front_0_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_0_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Front_Mid_1',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_back_1',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_back_1',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_back_1_edge_0',
#       'PointList': [{'ID': 'ins_skirt_back_1_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_1_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_1_edge_1',
#       'PointList': [{'ID': 'ins_skirt_back_1_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_1_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_1_edge_2',
#       'PointList': [{'ID': 'ins_skirt_back_1_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_1_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Back_Mid_3',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_front_1',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_front_1',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_front_1_edge_0',
#       'PointList': [{'ID': 'ins_skirt_front_1_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_1_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_1_edge_1',
#       'PointList': [{'ID': 'ins_skirt_front_1_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_1_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_1_edge_2',
#       'PointList': [{'ID': 'ins_skirt_front_1_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_1_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Front_Mid_1',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_back_2',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_back_2',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_back_2_edge_0',
#       'PointList': [{'ID': 'ins_skirt_back_2_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_2_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_2_edge_1',
#       'PointList': [{'ID': 'ins_skirt_back_2_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_2_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_2_edge_2',
#       'PointList': [{'ID': 'ins_skirt_back_2_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_2_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Skirt_Back_Center_2',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_front_2',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_front_2',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_front_2_edge_0',
#       'PointList': [{'ID': 'ins_skirt_front_2_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_2_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_2_edge_1',
#       'PointList': [{'ID': 'ins_skirt_front_2_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_2_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_2_edge_2',
#       'PointList': [{'ID': 'ins_skirt_front_2_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_2_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Skirt_Front_Center_1',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'skirt_back',
#    'fGrainlineAngle': 0.0,
#    'ID': 'skirt_back',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'skirt_back_edge_0',
#       'PointList': [{'ID': 'skirt_back_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -27.235078044982274, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_1',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -4.321017680108952e-06, 'y': 484.00126392389757},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_2',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -0.0, 'y': 484.00126392389757},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_3',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 646.805263981831},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_1',
#       'PointList': [{'ID': 'skirt_back_point_3',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 646.805263981831},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_4',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -1.1580289706603075e-06, 'y': 719.8943133693589},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_5',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -0.0, 'y': 719.8943133693589},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_6',
#         'PointType': 'Straight',
#         'Position': {'x': -12.571154454361617, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_2',
#       'PointList': [{'ID': 'skirt_back_point_6',
#         'PointType': 'Straight',
#         'Position': {'x': -12.571154454361617, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_7',
#         'PointType': 'Straight',
#         'Position': {'x': -102.36442364600452, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_3',
#       'PointList': [{'ID': 'skirt_back_point_7',
#         'PointType': 'Straight',
#         'Position': {'x': -102.36442364600452, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_8',
#         'PointType': 'Straight',
#         'Position': {'x': -110.80620264933819, 'y': 680.4180892696436},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_4',
#       'PointList': [{'ID': 'skirt_back_point_8',
#         'PointType': 'Straight',
#         'Position': {'x': -110.80620264933819, 'y': 680.4180892696436},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_9',
#         'PointType': 'Straight',
#         'Position': {'x': -119.24798165267185, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_5',
#       'PointList': [{'ID': 'skirt_back_point_9',
#         'PointType': 'Straight',
#         'Position': {'x': -119.24798165267185, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_10',
#         'PointType': 'Straight',
#         'Position': {'x': -157.99565615557475, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_6',
#       'PointList': [{'ID': 'skirt_back_point_10',
#         'PointType': 'Straight',
#         'Position': {'x': -157.99565615557475, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_11',
#         'PointType': 'Straight',
#         'Position': {'x': -166.43743515890844, 'y': 667.9005257929965},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_7',
#       'PointList': [{'ID': 'skirt_back_point_11',
#         'PointType': 'Straight',
#         'Position': {'x': -166.43743515890844, 'y': 667.9005257929965},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_12',
#         'PointType': 'Straight',
#         'Position': {'x': -174.8792141622421, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_8',
#       'PointList': [{'ID': 'skirt_back_point_12',
#         'PointType': 'Straight',
#         'Position': {'x': -174.8792141622421, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_13',
#         'PointType': 'Straight',
#         'Position': {'x': -291.1222388973938, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_9',
#       'PointList': [{'ID': 'skirt_back_point_13',
#         'PointType': 'Straight',
#         'Position': {'x': -291.1222388973938, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_14',
#         'PointType': 'Straight',
#         'Position': {'x': -299.5640179007275, 'y': 667.9005257929965},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_10',
#       'PointList': [{'ID': 'skirt_back_point_14',
#         'PointType': 'Straight',
#         'Position': {'x': -299.5640179007275, 'y': 667.9005257929965},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_15',
#         'PointType': 'Straight',
#         'Position': {'x': -308.0057969040611, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_11',
#       'PointList': [{'ID': 'skirt_back_point_15',
#         'PointType': 'Straight',
#         'Position': {'x': -308.0057969040611, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_16',
#         'PointType': 'Straight',
#         'Position': {'x': -346.7534701802334, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_12',
#       'PointList': [{'ID': 'skirt_back_point_16',
#         'PointType': 'Straight',
#         'Position': {'x': -346.7534701802334, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_17',
#         'PointType': 'Straight',
#         'Position': {'x': -355.19524918356717, 'y': 680.4180892696436},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_13',
#       'PointList': [{'ID': 'skirt_back_point_17',
#         'PointType': 'Straight',
#         'Position': {'x': -355.19524918356717, 'y': 680.4180892696436},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_18',
#         'PointType': 'Straight',
#         'Position': {'x': -363.63702818690075, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_14',
#       'PointList': [{'ID': 'skirt_back_point_18',
#         'PointType': 'Straight',
#         'Position': {'x': -363.63702818690075, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_19',
#         'PointType': 'Straight',
#         'Position': {'x': -453.4302955456384, 'y': 792.472146648262},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_15',
#       'PointList': [{'ID': 'skirt_back_point_19',
#         'PointType': 'Straight',
#         'Position': {'x': -453.4302955456384, 'y': 792.472146648262},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_20',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -466.0014488308278, 'y': 719.8943137165587},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_21',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -466.0014, 'y': 719.8943137165587},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_22',
#         'PointType': 'Straight',
#         'Position': {'x': -466.00145000000003, 'y': 646.805263981831},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_16',
#       'PointList': [{'ID': 'skirt_back_point_22',
#         'PointType': 'Straight',
#         'Position': {'x': -466.00145000000003, 'y': 646.805263981831},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_23',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -466.00144569893274, 'y': 484.00126562696244},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_24',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': -466.0014, 'y': 484.00126562696244},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_25',
#         'PointType': 'Straight',
#         'Position': {'x': -438.76637195501775, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_17',
#       'PointList': [{'ID': 'skirt_back_point_25',
#         'PointType': 'Straight',
#         'Position': {'x': -438.76637195501775, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_26',
#         'PointType': 'Straight',
#         'Position': {'x': -404.7663699060528, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_18',
#       'PointList': [{'ID': 'skirt_back_point_26',
#         'PointType': 'Straight',
#         'Position': {'x': -404.7663699060528, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_27',
#         'PointType': 'Straight',
#         'Position': {'x': -397.6132405150492, 'y': 366.83599229071785},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_19',
#       'PointList': [{'ID': 'skirt_back_point_27',
#         'PointType': 'Straight',
#         'Position': {'x': -397.6132405150492, 'y': 366.83599229071785},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_28',
#         'PointType': 'Straight',
#         'Position': {'x': -390.4601111240457, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_20',
#       'PointList': [{'ID': 'skirt_back_point_28',
#         'PointType': 'Straight',
#         'Position': {'x': -390.4601111240457, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_29',
#         'PointType': 'Straight',
#         'Position': {'x': -322.460109304667, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_21',
#       'PointList': [{'ID': 'skirt_back_point_29',
#         'PointType': 'Straight',
#         'Position': {'x': -322.460109304667, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_30',
#         'PointType': 'Straight',
#         'Position': {'x': -315.30697991366344, 'y': 366.83599229071785},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_22',
#       'PointList': [{'ID': 'skirt_back_point_30',
#         'PointType': 'Straight',
#         'Position': {'x': -315.30697991366344, 'y': 366.83599229071785},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_31',
#         'PointType': 'Straight',
#         'Position': {'x': -308.1538505226599, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_23',
#       'PointList': [{'ID': 'skirt_back_point_31',
#         'PointType': 'Straight',
#         'Position': {'x': -308.1538505226599, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_32',
#         'PointType': 'Straight',
#         'Position': {'x': -240.15384911113486, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_24',
#       'PointList': [{'ID': 'skirt_back_point_32',
#         'PointType': 'Straight',
#         'Position': {'x': -240.15384911113486, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_33',
#         'PointType': 'Straight',
#         'Position': {'x': -233.0007197201313, 'y': 366.83599229071785},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_25',
#       'PointList': [{'ID': 'skirt_back_point_33',
#         'PointType': 'Straight',
#         'Position': {'x': -233.0007197201313, 'y': 366.83599229071785},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_34',
#         'PointType': 'Straight',
#         'Position': {'x': -225.8475903291278, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_26',
#       'PointList': [{'ID': 'skirt_back_point_34',
#         'PointType': 'Straight',
#         'Position': {'x': -225.8475903291278, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_35',
#         'PointType': 'Straight',
#         'Position': {'x': -157.84758938670794, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_27',
#       'PointList': [{'ID': 'skirt_back_point_35',
#         'PointType': 'Straight',
#         'Position': {'x': -157.84758938670794, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_36',
#         'PointType': 'Straight',
#         'Position': {'x': -150.69445999570434, 'y': 366.83599229071785},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_28',
#       'PointList': [{'ID': 'skirt_back_point_36',
#         'PointType': 'Straight',
#         'Position': {'x': -150.69445999570434, 'y': 366.83599229071785},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_37',
#         'PointType': 'Straight',
#         'Position': {'x': -143.5413306047008, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_29',
#       'PointList': [{'ID': 'skirt_back_point_37',
#         'PointType': 'Straight',
#         'Position': {'x': -143.5413306047008, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_38',
#         'PointType': 'Straight',
#         'Position': {'x': -75.54133086788994, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_30',
#       'PointList': [{'ID': 'skirt_back_point_38',
#         'PointType': 'Straight',
#         'Position': {'x': -75.54133086788994, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_39',
#         'PointType': 'Straight',
#         'Position': {'x': -68.38820147688634, 'y': 366.83599229071785},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_31',
#       'PointList': [{'ID': 'skirt_back_point_39',
#         'PointType': 'Straight',
#         'Position': {'x': -68.38820147688634, 'y': 366.83599229071785},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_40',
#         'PointType': 'Straight',
#         'Position': {'x': -61.235072085882834, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_back_edge_32',
#       'PointList': [{'ID': 'skirt_back_point_40',
#         'PointType': 'Straight',
#         'Position': {'x': -61.235072085882834, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_back_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -27.235078044982274, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Body_Back_Center_10',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'skirt_front',
#    'fGrainlineAngle': 0.0,
#    'ID': 'skirt_front',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'skirt_front_edge_0',
#       'PointList': [{'ID': 'skirt_front_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 27.235078044982274, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 58.89421923480085, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_1',
#       'PointList': [{'ID': 'skirt_front_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 58.89421923480085, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 63.14421923480085, 'y': 366.8811115334231},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_2',
#       'PointList': [{'ID': 'skirt_front_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 63.14421923480085, 'y': 366.8811115334231},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_3',
#         'PointType': 'Straight',
#         'Position': {'x': 67.39421923480086, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_3',
#       'PointList': [{'ID': 'skirt_front_point_3',
#         'PointType': 'Straight',
#         'Position': {'x': 67.39421923480086, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_4',
#         'PointType': 'Straight',
#         'Position': {'x': 130.7124996171064, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_4',
#       'PointList': [{'ID': 'skirt_front_point_4',
#         'PointType': 'Straight',
#         'Position': {'x': 130.7124996171064, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_5',
#         'PointType': 'Straight',
#         'Position': {'x': 134.9624996171064, 'y': 366.8811115334231},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_5',
#       'PointList': [{'ID': 'skirt_front_point_5',
#         'PointType': 'Straight',
#         'Position': {'x': 134.9624996171064, 'y': 366.8811115334231},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_6',
#         'PointType': 'Straight',
#         'Position': {'x': 139.21249961710637, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_6',
#       'PointList': [{'ID': 'skirt_front_point_6',
#         'PointType': 'Straight',
#         'Position': {'x': 139.21249961710637, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_7',
#         'PointType': 'Straight',
#         'Position': {'x': 202.53077963847102, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_7',
#       'PointList': [{'ID': 'skirt_front_point_7',
#         'PointType': 'Straight',
#         'Position': {'x': 202.53077963847102, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_8',
#         'PointType': 'Straight',
#         'Position': {'x': 206.78077963847102, 'y': 366.8811115334231},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_8',
#       'PointList': [{'ID': 'skirt_front_point_8',
#         'PointType': 'Straight',
#         'Position': {'x': 206.78077963847102, 'y': 366.8811115334231},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_9',
#         'PointType': 'Straight',
#         'Position': {'x': 211.03077963847102, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_9',
#       'PointList': [{'ID': 'skirt_front_point_9',
#         'PointType': 'Straight',
#         'Position': {'x': 211.03077963847102, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_10',
#         'PointType': 'Straight',
#         'Position': {'x': 274.3490592862953, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_10',
#       'PointList': [{'ID': 'skirt_front_point_10',
#         'PointType': 'Straight',
#         'Position': {'x': 274.3490592862953, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_11',
#         'PointType': 'Straight',
#         'Position': {'x': 278.5990592862953, 'y': 366.8811115334231},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_11',
#       'PointList': [{'ID': 'skirt_front_point_11',
#         'PointType': 'Straight',
#         'Position': {'x': 278.5990592862953, 'y': 366.8811115334231},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_12',
#         'PointType': 'Straight',
#         'Position': {'x': 282.8490592862953, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_12',
#       'PointList': [{'ID': 'skirt_front_point_12',
#         'PointType': 'Straight',
#         'Position': {'x': 282.8490592862953, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_13',
#         'PointType': 'Straight',
#         'Position': {'x': 346.16733858486504, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_13',
#       'PointList': [{'ID': 'skirt_front_point_13',
#         'PointType': 'Straight',
#         'Position': {'x': 346.16733858486504, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_14',
#         'PointType': 'Straight',
#         'Position': {'x': 350.41733858486504, 'y': 366.8811115334231},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_14',
#       'PointList': [{'ID': 'skirt_front_point_14',
#         'PointType': 'Straight',
#         'Position': {'x': 350.41733858486504, 'y': 366.8811115334231},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_15',
#         'PointType': 'Straight',
#         'Position': {'x': 354.66733858486504, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_15',
#       'PointList': [{'ID': 'skirt_front_point_15',
#         'PointType': 'Straight',
#         'Position': {'x': 354.66733858486504, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_16',
#         'PointType': 'Straight',
#         'Position': {'x': 386.32647195501767, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_16',
#       'PointList': [{'ID': 'skirt_front_point_16',
#         'PointType': 'Straight',
#         'Position': {'x': 386.32647195501767, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_17',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 413.56154569893266, 'y': 484.00126562696244},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_18',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 413.5615, 'y': 484.00126562696244},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_19',
#         'PointType': 'Straight',
#         'Position': {'x': 413.56154999999995, 'y': 646.805263981831},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_17',
#       'PointList': [{'ID': 'skirt_front_point_19',
#         'PointType': 'Straight',
#         'Position': {'x': 413.56154999999995, 'y': 646.805263981831},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_20',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 413.5614412230111, 'y': 716.3444624514856},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_21',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 413.5614, 'y': 716.3444624514856},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_22',
#         'PointType': 'Straight',
#         'Position': {'x': 403.35247394664043, 'y': 785.535628426051},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_18',
#       'PointList': [{'ID': 'skirt_front_point_22',
#         'PointType': 'Straight',
#         'Position': {'x': 403.35247394664043, 'y': 785.535628426051},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_23',
#         'PointType': 'Straight',
#         'Position': {'x': 10.209076053359503, 'y': 785.535628426051},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_19',
#       'PointList': [{'ID': 'skirt_front_point_23',
#         'PointType': 'Straight',
#         'Position': {'x': 10.209076053359503, 'y': 785.535628426051},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_24',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 0.00010877031973272056, 'y': 716.3444622995283},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_25',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 0.0001, 'y': 716.3444622995283},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_26',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 646.805263981831},
#         'GradingRuleID': -1}]},
#      {'ID': 'skirt_front_edge_20',
#       'PointList': [{'ID': 'skirt_front_point_26',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 646.805263981831},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_27',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 4.321017681052641e-06, 'y': 484.00126392389757},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_28',
#         'PointType': 'Bezier Curve',
#         'Position': {'x': 0.0, 'y': 484.00126392389757},
#         'GradingRuleID': -1},
#        {'ID': 'skirt_front_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 27.235078044982274, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Body_Front_Center_9',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_back_3',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_back_3',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_back_3_edge_0',
#       'PointList': [{'ID': 'ins_skirt_back_3_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_3_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_3_edge_1',
#       'PointList': [{'ID': 'ins_skirt_back_3_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_3_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_3_edge_2',
#       'PointList': [{'ID': 'ins_skirt_back_3_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_3_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Back_Mid_1',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_front_3',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_front_3',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_front_3_edge_0',
#       'PointList': [{'ID': 'ins_skirt_front_3_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_3_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_3_edge_1',
#       'PointList': [{'ID': 'ins_skirt_front_3_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_3_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_3_edge_2',
#       'PointList': [{'ID': 'ins_skirt_front_3_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_3_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Front_Mid_3',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_back_4',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_back_4',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_back_4_edge_0',
#       'PointList': [{'ID': 'ins_skirt_back_4_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_4_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_4_edge_1',
#       'PointList': [{'ID': 'ins_skirt_back_4_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': -114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_4_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_back_4_edge_2',
#       'PointList': [{'ID': 'ins_skirt_back_4_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': -229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_back_4_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': -0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Back_Mid_1',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}},
#   {'Name': 'ins_skirt_front_4',
#    'fGrainlineAngle': 0.0,
#    'ID': 'ins_skirt_front_4',
#    'strSuperImposeSide': 'None',
#    'CurrentFabricUUID': 'DWX6ey',
#    'IsClosed': False,
#    'InternalLineList': [],
#    'ButtonHeadList': [],
#    'ButtonHoleList': [],
#    'AnnotationList': [],
#    'NotchList': [],
#    'IsHalfSymmetric': False,
#    'ShapeInfo': {'IsSlashed': False,
#     'LineList': [{'ID': 'ins_skirt_front_4_edge_0',
#       'PointList': [{'ID': 'ins_skirt_front_4_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_4_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_4_edge_1',
#       'PointList': [{'ID': 'ins_skirt_front_4_point_1',
#         'PointType': 'Straight',
#         'Position': {'x': 229.5, 'y': 0.0},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_4_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1}]},
#      {'ID': 'ins_skirt_front_4_edge_2',
#       'PointList': [{'ID': 'ins_skirt_front_4_point_2',
#         'PointType': 'Straight',
#         'Position': {'x': 114.75, 'y': 348.5},
#         'GradingRuleID': -1},
#        {'ID': 'ins_skirt_front_4_point_0',
#         'PointType': 'Straight',
#         'Position': {'x': 0.0, 'y': 0.0},
#         'GradingRuleID': -1}]}],
#     'HalfSymmetryPointIDMap': {},
#     'HalfSymmetryLineIDMap': {}},
#    'ArrangementPointDataMap': {'PointName': 'Leg_Front_Mid_3',
#     'fOffSetX': 0.0,
#     'fOffSetY': 0.05,
#     'fAngle': 180.0}}],
#  'SymmetricDataList': [],
#  'InstanceDataList': [{'OriginPatternID': 'ins_skirt_back_0',
#    'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_front_0', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_back_1', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_front_1', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_back_2', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_front_2', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'skirt_back', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'skirt_front', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_back_3', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_front_3', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_back_4', 'InstancePatternIDArray': []},
#   {'OriginPatternID': 'ins_skirt_front_4', 'InstancePatternIDArray': []}],
#  'SeamLinePairGroupList': [{'Name': 'SeamLineGroup_0',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.127734, 'fEnd': 0.143974},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.160214, 'fEnd': 0.143974},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_1',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.165814, 'fEnd': 0.183859},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.201903, 'fEnd': 0.183859},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_2',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.218703, 'fEnd': 0.236747},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.254792, 'fEnd': 0.236747},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_3',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.260392, 'fEnd': 0.276632},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.292872, 'fEnd': 0.276632},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_4',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.891222, 'fEnd': 1.0},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.093577, 'fEnd': 0.0},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_5',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.867813, 'fEnd': 0.891222},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.114757, 'fEnd': 0.093577},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_6',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.778356, 'fEnd': 0.801766},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.327029, 'fEnd': 0.305849},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_7',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.669578, 'fEnd': 0.778356},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.420606, 'fEnd': 0.327029},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_8',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_0',
#       'LengthParam': {'fStart': 0.61912, 'fEnd': 1.0},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.066958, 'fEnd': 0.005319},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_9',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_0',
#       'LengthParam': {'fStart': 0.238241, 'fEnd': 0.61912},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.128597, 'fEnd': 0.066958},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_10',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_1',
#       'LengthParam': {'fStart': 0.61912, 'fEnd': 1.0},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.200873, 'fEnd': 0.139234},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_11',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_1',
#       'LengthParam': {'fStart': 0.238241, 'fEnd': 0.61912},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.262513, 'fEnd': 0.200873},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_12',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_2',
#       'LengthParam': {'fStart': 0.61912, 'fEnd': 1.0},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.334789, 'fEnd': 0.27315},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_13',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_2',
#       'LengthParam': {'fStart': 0.238241, 'fEnd': 0.61912},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.396428, 'fEnd': 0.334789},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_14',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_3',
#       'LengthParam': {'fStart': 0.61912, 'fEnd': 1.0},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.468705, 'fEnd': 0.407066},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_15',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_3',
#       'LengthParam': {'fStart': 0.238241, 'fEnd': 0.61912},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.530344, 'fEnd': 0.468705},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_16',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_4',
#       'LengthParam': {'fStart': 0.61912, 'fEnd': 1.0},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.60262, 'fEnd': 0.540981},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_17',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_front_4',
#       'LengthParam': {'fStart': 0.238241, 'fEnd': 0.61912},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_front',
#       'LengthParam': {'fStart': 0.664259, 'fEnd': 0.60262},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_18',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_4',
#       'LengthParam': {'fStart': 0.0, 'fEnd': 0.38088},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.531571, 'fEnd': 0.478546},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_19',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_4',
#       'LengthParam': {'fStart': 0.38088, 'fEnd': 0.761759},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.478546, 'fEnd': 0.42552},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_20',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_3',
#       'LengthParam': {'fStart': 0.0, 'fEnd': 0.38088},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.64745, 'fEnd': 0.594424},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_21',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_3',
#       'LengthParam': {'fStart': 0.38088, 'fEnd': 0.761759},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.594424, 'fEnd': 0.541399},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_22',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_2',
#       'LengthParam': {'fStart': 0.0, 'fEnd': 0.38088},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.763329, 'fEnd': 0.710303},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_23',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_2',
#       'LengthParam': {'fStart': 0.38088, 'fEnd': 0.761759},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.710303, 'fEnd': 0.657278},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_24',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_1',
#       'LengthParam': {'fStart': 0.0, 'fEnd': 0.38088},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.879208, 'fEnd': 0.826182},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_25',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_1',
#       'LengthParam': {'fStart': 0.38088, 'fEnd': 0.761759},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.826182, 'fEnd': 0.773156},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_26',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_0',
#       'LengthParam': {'fStart': 0.0, 'fEnd': 0.38088},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.995086, 'fEnd': 0.942061},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}},
#   {'Name': 'SeamLineGroup_27',
#    'bIsTurned': False,
#    'PairList': [{'First': {'ShapeID': 'ins_skirt_back_0',
#       'LengthParam': {'fStart': 0.38088, 'fEnd': 0.761759},
#       'Direction': True},
#      'Second': {'ShapeID': 'skirt_back',
#       'LengthParam': {'fStart': 0.942061, 'fEnd': 0.889035},
#       'Direction': False}}],
#    'FoldData': {'iAngle': 180, 'iStrength': 5}}]}

# %%
# def main():
#     count = 10  # 원하는 생성 횟수
#     generated = set()  # 중복 방지를 위해 생성된 문자열을 저장할 집합

#     for _ in range(count):
#         unique_str = get_unique_random_string(generated)
#         print(unique_str)

# if __name__ == "__main__":
#     main()
# Out:
# eHbHTE
# aIxD6q
# GAWImH
# pShztH
# JBpWQB
# pcfbJI
# gZDM9r
# Okjcmv
# 1BjKTd
# MxLJXr

# %%
GARMENT_PATH_1 = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/uni_test_test/garments_5000_0_rand_0ADI18HWRF/Clo_Garment_garments_5000_0_rand_0ADI18HWRF.json"
GARMENT_PATH_2 = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/uni_test_test/garments_5000_0_rand_0BVS2KDJ6H/Clo_Garment_garments_5000_0_rand_0BVS2KDJ6H.json"

uni_data = unify_clo_json_data(GARMENT_PATH_1, GARMENT_PATH_2)

# %%
STITCH_PATH_1 = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/uni_test_test/garments_5000_0_rand_0ADI18HWRF/Clo_Stitch_garments_5000_0_rand_0ADI18HWRF.json"
STITCH_PATH_2 = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/uni_test_test/garments_5000_0_rand_0BVS2KDJ6H/Clo_Stitch_garments_5000_0_rand_0BVS2KDJ6H.json"


stitch_data, garment_list = stitch_data_unify(STITCH_PATH_1, STITCH_PATH_2)

# %%
SAVE_PATH = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/uni_test_test"
with open(f"{SAVE_PATH}/Clo_Garment_Unify.json", "w") as file:
    json.dump(uni_data, file, indent=4)
with open(f"{SAVE_PATH}/Clo_Stitch_Unify.json", "w") as file:
    json.dump(stitch_data, file, indent=4)
with open(f"{SAVE_PATH}/Clo_garment_id.json", "w") as file:
    json.dump(garment_list, file, indent=4)

# %%
# Out:
# [{'panel': 1, 'edge': 3},
#  {'panel': 0, 'edge': 0},
#  {'panel': 1, 'edge': 1},
#  {'panel': 0, 'edge': 2},
#  {'panel': 3, 'edge': 3},
#  {'panel': 2, 'edge': 0},
#  {'panel': 3, 'edge': 1},
#  {'panel': 2, 'edge': 2},
#  {'panel': 3, 'edge': 0},
#  {'panel': 1, 'edge': 2},
#  {'panel': 2, 'edge': 3},
#  {'panel': 0, 'edge': 1},
#  {'panel': 5, 'edge': 2},
#  {'panel': 4, 'edge': 3},
#  {'panel': 5, 'edge': 4},
#  {'panel': 4, 'edge': 1},
#  {'panel': 7, 'edge': 3},
#  {'panel': 6, 'edge': 2},
#  {'panel': 7, 'edge': 1},
#  {'panel': 6, 'edge': 4},
#  {'panel': 5, 'edge': 0},
#  {'panel': 7, 'edge': 5},
#  {'panel': 4, 'edge': 5},
#  {'panel': 6, 'edge': 0}]

# %%
def stitch_data_unify(Clo_stitch_path, Clo_stitch_path_to_add):
    with open(Clo_stitch_path, "r") as f:
        stitch_data_1 = json.load(f)
    #stitch_data_1
    with open(Clo_stitch_path_to_add, "r") as f:
        stitch_data_2 = json.load(f)
    
    max_panel_1 = max(d["panel"] for d in stitch_data_1)
    offset = max_panel_1 + 1
    for item in stitch_data_2:
        item["panel"] += offset
    return stitch_data_1.extend(stitch_data_2)

# %%
stitch_data_unify()

# %%
PATH = "/media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/Unify_Clo_json_data"

path123 = os.path.join(PATH, "case_2")
print(path123)
# Out:
# /media/hjp/db6095ca-a560-4c3a-90ad-b667ec189671/REFERENCES/3D_VTO/GarmentCode/GarmentCode/ANALYSIS_josef/Unify_Clo_json_data/case_2
